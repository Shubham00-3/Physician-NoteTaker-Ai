# %% [markdown]
# # Physician Notetaker AI
#
# Quick demo of the local NLP pipeline: entities, summary, keywords, sentiment/intent, and SOAP note generation.

# %%
from pathlib import Path
import json

from src.pipeline import MedicalNLPipeline

transcript_path = Path("../data/sample_transcript.txt")
text = transcript_path.read_text(encoding="utf-8")
print(f"Loaded transcript from {transcript_path.resolve()}")

# %%
pipeline = MedicalNLPipeline()
result = pipeline.run_all(text)
print(json.dumps(result, indent=2))
